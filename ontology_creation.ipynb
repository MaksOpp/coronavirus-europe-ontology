# %%
import pandas as pd
data = pd.read_csv('test_sheet.csv')

# %%
data.head()
# Out:
#                       Subject Label  \
# 0         Milton Joseph Batiste Jr.
# 1         Milton Joseph Batiste Jr.
# 2                Milton Batiste Sr.
# 3  Feliciana Mary Jolivette Batiste
# 4                Milton Batiste Sr.
#
#                                       Subject URI Predicate Label  \
# 0  http://id.loc.gov/authorities/names/no99007541          Son Of
# 1  http://id.loc.gov/authorities/names/no99007541          Son Of
# 2                                            None       Father Of
# 3                                            None       Mother Of
# 4                                            None       Spouse Of
#
#    Predicate URI Predicate Symmetry                      Object Label  \
# 0            NaN         Asymmetric                Milton Batiste Sr.
# 1            NaN         Asymmetric  Feliciana Mary Jolivette Batiste
# 2            NaN         Asymmetric         Milton Joseph Batiste Jr.
# ...
